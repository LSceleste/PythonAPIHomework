# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations (latitude is HORIZONTAL, longitude is VERTIVCAL)
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

#zipping together both lat and long to give a set of coordinates to look up nearest city
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
# searching for the nearest city in a random way based on lat and lng 
for lat_lng in lat_lngs:
    #what do the 0,1 refer to in this instance? these are the first indexes of lat & lng
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list What does this line mean? Ask for breakdown
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
#Need to build query url in order to request at least 500 city lookups based on random list of coordinates

lat_list = []
lng_list = []
city_list = []
maxtemp_list = []
cloud_list = []
wind_list = []
humidity_list = []

count = 0 
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric" 

query_url = f"{url}appid={api_key}&units={units}&q="
print(query_url)

#make new dataframe for information retrieved

# do this line at the end city_weather_df = pd.DataFrame(columns = ["City","Country","Lat","Lng","Date","Max Temp", "Wind Speed", 
                                          # "Cloudiness" , "Humidity"])
for city in cities: 
    print(city)
    
    try: 
        response = requests.get(query_url + city).json()
        print(response)
        #lat_value = response(["coord"]["lat"])
        #print(lat_value)
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        city_list.append(response["name"])
        maxtemp_list.append(response["main"]["temp_max"])
        cloud_list.append(response["clouds"]["all"])
        wind_list.append(response["wind"]["speed"])
        humidity_list.append(response["main"]["humidity"])
        count = count + 1
        print(len(lat_list))
        print(len(lng_list))
        print(len(city_list))
        print(len(maxtemp_list))
        print(len(cloud_list))
        print(len(wind_list))
        print(len(humidity_list))
        
        
    except KeyError: 
        print("Error retrieving city weather" + city)
        pass

print(len(lat_list))
print(len(lng_list))
print(len(city_list))
print(len(maxtemp_list))
print(len(cloud_list))
print(len(wind_list))
print(len(humidity_list))
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=df75ba845511ccd0e823e76f17dfed0f&units=metric&q=
# albany
# {'coord': {'lon': -73.75, 'lat': 42.65}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}, {'id': 301, 'main': 'Drizzle', 'description': 'drizzle', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 7.01, 'pressure': 1018, 'humidity': 81, 'temp_min': 5, 'temp_max': 8.33}, 'visibility': 8047, 'wind': {'speed': 3.1, 'deg': 180}, 'rain': {'1h': 0.51}, 'clouds': {'all': 90}, 'dt': 1553877209, 'sys': {'type': 1, 'id': 3273, 'message': 0.0076, 'country': 'US', 'sunrise': 1553856168, 'sunset': 1553901395}, 'id': 5106834, 'name': 'Albany', 'cod': 200}
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# barrow
# {'coord': {'lon': -60.23, 'lat': -38.31}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 24.27, 'pressure': 1015.41, 'humidity': 59, 'temp_min': 24.27, 'temp_max': 24.27, 'sea_level': 1015.41, 'grnd_level': 1003.87}, 'wind': {'speed': 7.36, 'deg': 340.502}, 'clouds': {'all': 36}, 'dt': 1553877338, 'sys': {'message': 0.0034, 'country': 'AR', 'sunrise': 1553854316, 'sunset': 1553896759}, 'id': 3833859, 'name': 'Barrow', 'cod': 200}
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# ribeira grande
# {'coord': {'lon': -28.7, 'lat': 38.52}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 16, 'pressure': 1025, 'humidity': 63, 'temp_min': 16, 'temp_max': 16}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 240}, 'clouds': {'all': 20}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 6883, 'message': 0.0039, 'country': 'PT', 'sunrise': 1553845485, 'sunset': 1553890458}, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# dikson
# {'coord': {'lon': 80.55, 'lat': 73.51}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -4.04, 'pressure': 1001.37, 'humidity': 95, 'temp_min': -4.04, 'temp_max': -4.04, 'sea_level': 1001.37, 'grnd_level': 1000.83}, 'wind': {'speed': 7.96, 'deg': 210.502}, 'clouds': {'all': 76}, 'dt': 1553877235, 'sys': {'message': 0.0038, 'country': 'RU', 'sunrise': 1553816841, 'sunset': 1553866674}, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# nizhneyansk
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weathernizhneyansk
# weinan
# {'coord': {'lon': 109.46, 'lat': 34.5}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 15, 'pressure': 1019, 'humidity': 12, 'temp_min': 15, 'temp_max': 15}, 'visibility': 10000, 'wind': {'speed': 5, 'deg': 50}, 'clouds': {'all': 0}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 9645, 'message': 0.0038, 'country': 'CN', 'sunrise': 1553898774, 'sunset': 1553943629}, 'id': 1791636, 'name': 'Weinan', 'cod': 200}
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# samusu
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weathersamusu
# keti bandar
# {'coord': {'lon': 67.45, 'lat': 24.14}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 26.52, 'pressure': 1011.49, 'humidity': 84, 'temp_min': 26.52, 'temp_max': 26.52, 'sea_level': 1011.49, 'grnd_level': 1011.31}, 'wind': {'speed': 7.61, 'deg': 287.002}, 'clouds': {'all': 8}, 'dt': 1553877341, 'sys': {'message': 0.0027, 'country': 'PK', 'sunrise': 1553822738, 'sunset': 1553867064}, 'id': 1174451, 'name': 'Keti Bandar', 'cod': 200}
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# iqaluit
# {'coord': {'lon': -68.52, 'lat': 63.75}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': -4.53, 'pressure': 983, 'humidity': 85, 'temp_min': -5, 'temp_max': -4}, 'visibility': 2414, 'wind': {'speed': 4.6, 'deg': 140}, 'clouds': {'all': 90}, 'dt': 1553877122, 'sys': {'type': 1, 'id': 797, 'message': 0.0086, 'country': 'CA', 'sunrise': 1553853839, 'sunset': 1553901214}, 'id': 5983720, 'name': 'Iqaluit', 'cod': 200}
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# qaanaaq
# {'coord': {'lon': -69.36, 'lat': 77.48}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': -19.94, 'pressure': 1014.49, 'humidity': 75, 'temp_min': -19.94, 'temp_max': -19.94, 'sea_level': 1014.49, 'grnd_level': 980.99}, 'wind': {'speed': 3.91, 'deg': 97.0016}, 'clouds': {'all': 12}, 'dt': 1553877226, 'sys': {'message': 0.0035, 'country': 'GL', 'sunrise': 1553851503, 'sunset': 1553903953}, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# ushuaia
# {'coord': {'lon': -68.31, 'lat': -54.81}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 11.8, 'pressure': 973, 'humidity': 58, 'temp_min': 10, 'temp_max': 14}, 'visibility': 10000, 'wind': {'speed': 16.5, 'deg': 230, 'gust': 27.8}, 'clouds': {'all': 75}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 8303, 'message': 0.0036, 'country': 'AR', 'sunrise': 1553856669, 'sunset': 1553898283}, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# hilo
# {'coord': {'lon': -155.08, 'lat': 19.71}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 16.68, 'pressure': 1015, 'humidity': 72, 'temp_min': 14.44, 'temp_max': 18}, 'visibility': 16093, 'wind': {'speed': 2.6, 'deg': 230}, 'clouds': {'all': 40}, 'dt': 1553877226, 'sys': {'type': 1, 'id': 7881, 'message': 0.004, 'country': 'US', 'sunrise': 1553876188, 'sunset': 1553920404}, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# verkhnevilyuysk
# {'coord': {'lon': 120.31, 'lat': 63.45}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -11.74, 'pressure': 1021.49, 'humidity': 58, 'temp_min': -11.74, 'temp_max': -11.74, 'sea_level': 1021.49, 'grnd_level': 1003.71}, 'wind': {'speed': 1.16, 'deg': 182.002}, 'clouds': {'all': 64}, 'dt': 1553877342, 'sys': {'message': 0.0033, 'country': 'RU', 'sunrise': 1553894846, 'sunset': 1553942350}, 'id': 2013639, 'name': 'Verkhnevilyuysk', 'cod': 200}
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# hovd
# {'coord': {'lon': 10.7, 'lat': 63.83}, 'weather': [{'id': 300, 'main': 'Drizzle', 'description': 'light intensity drizzle', 'icon': '09d'}, {'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 2.16, 'pressure': 1007, 'humidity': 93, 'temp_min': 0, 'temp_max': 4.44}, 'visibility': 8000, 'wind': {'speed': 3.6, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1553877316, 'sys': {'type': 1, 'id': 1676, 'message': 0.0042, 'country': 'NO', 'sunrise': 1553834865, 'sunset': 1553882170}, 'id': 7626384, 'name': 'Hovd', 'cod': 200}
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# vaini
# {'coord': {'lon': 74.49, 'lat': 15.34}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 22.57, 'pressure': 1011.41, 'humidity': 87, 'temp_min': 22.57, 'temp_max': 22.57, 'sea_level': 1011.41, 'grnd_level': 947.47}, 'wind': {'speed': 1.46, 'deg': 260.502}, 'clouds': {'all': 0}, 'dt': 1553877343, 'sys': {'message': 0.003, 'country': 'IN', 'sunrise': 1553821194, 'sunset': 1553865229}, 'id': 1273574, 'name': 'Vaini', 'cod': 200}
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# plettenberg bay
# {'coord': {'lon': 23.37, 'lat': -34.05}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 19.27, 'pressure': 1013.85, 'humidity': 99, 'temp_min': 19.27, 'temp_max': 19.27, 'sea_level': 1013.85, 'grnd_level': 1007.07}, 'wind': {'speed': 4.01, 'deg': 87.5016}, 'clouds': {'all': 0}, 'dt': 1553877343, 'sys': {'message': 0.0042, 'country': 'ZA', 'sunrise': 1553834163, 'sunset': 1553876792}, 'id': 964712, 'name': 'Plettenberg Bay', 'cod': 200}
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# sungairaya
# {'coord': {'lon': 108.9, 'lat': 0.7}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 24.87, 'pressure': 1009.85, 'humidity': 90, 'temp_min': 24.87, 'temp_max': 24.87, 'sea_level': 1009.85, 'grnd_level': 999.71}, 'wind': {'speed': 1.21, 'deg': 220.502}, 'clouds': {'all': 36}, 'dt': 1553877344, 'sys': {'message': 0.0033, 'country': 'ID', 'sunrise': 1553813146, 'sunset': 1553856764}, 'id': 1625908, 'name': 'Sungairaya', 'cod': 200}
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# mataura
# {'coord': {'lon': 168.86, 'lat': -46.19}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 9.44, 'pressure': 1028, 'humidity': 96, 'temp_min': 9.44, 'temp_max': 9.44}, 'wind': {'speed': 1.21, 'deg': 5.50162}, 'clouds': {'all': 0}, 'dt': 1553877008, 'sys': {'type': 3, 'id': 2008959, 'message': 0.0035, 'country': 'NZ', 'sunrise': 1553885931, 'sunset': 1553927967}, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# saskylakh
# {'coord': {'lon': 114.09, 'lat': 71.97}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': -8.59, 'pressure': 1011.65, 'humidity': 75, 'temp_min': -8.59, 'temp_max': -8.59, 'sea_level': 1011.65, 'grnd_level': 999.55}, 'wind': {'speed': 6.51, 'deg': 240.502}, 'clouds': {'all': 20}, 'dt': 1553877344, 'sys': {'message': 0.0034, 'country': 'RU', 'sunrise': 1553895205, 'sunset': 1553944976}, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# okato
# {'coord': {'lon': 173.88, 'lat': -39.19}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 17.78, 'pressure': 1021, 'humidity': 83, 'temp_min': 17.78, 'temp_max': 17.78}, 'wind': {'speed': 4.66, 'deg': 81.5016}, 'rain': {}, 'clouds': {'all': 64}, 'dt': 1553876778, 'sys': {'type': 3, 'id': 20034, 'message': 0.0035, 'country': 'NZ', 'sunrise': 1553884567, 'sunset': 1553926922}, 'id': 2185763, 'name': 'Okato', 'cod': 200}
# 18
# 18
# 18
# 18
# 18
# 18
# 18
# sur
# {'coord': {'lon': 59.53, 'lat': 22.57}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 24.42, 'pressure': 1015.45, 'humidity': 91, 'temp_min': 24.42, 'temp_max': 24.42, 'sea_level': 1015.45, 'grnd_level': 985.07}, 'wind': {'speed': 3.11, 'deg': 298.502}, 'clouds': {'all': 0}, 'dt': 1553877345, 'sys': {'message': 0.0034, 'country': 'OM', 'sunrise': 1553824665, 'sunset': 1553868937}, 'id': 286245, 'name': 'Sur', 'cod': 200}
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# sitka
# {'coord': {'lon': -99.65, 'lat': 37.17}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 6.11, 'pressure': 1013, 'humidity': 98, 'temp_min': 6.11, 'temp_max': 6.11}, 'wind': {'speed': 3.13, 'deg': 121, 'gust': 4.92}, 'rain': {'3h': 0.02}, 'clouds': {'all': 76}, 'dt': 1553877066, 'sys': {'type': 3, 'id': 2005167, 'message': 0.0031, 'country': 'US', 'sunrise': 1553862530, 'sunset': 1553907462}, 'id': 4267710, 'name': 'Sitka', 'cod': 200}
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# east london
# {'coord': {'lon': 27.91, 'lat': -33.02}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 23, 'pressure': 1017, 'humidity': 69, 'temp_min': 23, 'temp_max': 23}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 90}, 'clouds': {'all': 0}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 1912, 'message': 0.0034, 'country': 'ZA', 'sunrise': 1553833056, 'sunset': 1553875721}, 'id': 1006984, 'name': 'East London', 'cod': 200}
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# puerto ayora
# {'coord': {'lon': -90.35, 'lat': -0.74}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 28.11, 'pressure': 1013, 'humidity': 74, 'temp_min': 27.22, 'temp_max': 29}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 100}, 'clouds': {'all': 20}, 'dt': 1553877139, 'sys': {'type': 1, 'id': 8521, 'message': 0.0043, 'country': 'EC', 'sunrise': 1553860975, 'sunset': 1553904554}, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# tuatapere
# {'coord': {'lon': 167.69, 'lat': -46.13}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 9.44, 'pressure': 1028, 'humidity': 96, 'temp_min': 9.44, 'temp_max': 9.44}, 'wind': {'speed': 1.66, 'deg': 49.5016}, 'clouds': {'all': 8}, 'dt': 1553877008, 'sys': {'type': 3, 'id': 2008959, 'message': 0.0035, 'country': 'NZ', 'sunrise': 1553886211, 'sunset': 1553928248}, 'id': 2180815, 'name': 'Tuatapere', 'cod': 200}
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# graham
# {'coord': {'lon': -79.4, 'lat': 36.07}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 20.86, 'pressure': 1022, 'humidity': 26, 'temp_min': 19, 'temp_max': 22.22}, 'visibility': 16093, 'wind': {'speed': 3.6, 'deg': 210}, 'clouds': {'all': 1}, 'dt': 1553877334, 'sys': {'type': 1, 'id': 3521, 'message': 0.0066, 'country': 'US', 'sunrise': 1553857703, 'sunset': 1553902572}, 'id': 4468525, 'name': 'Graham', 'cod': 200}
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# aloleng
# {'coord': {'lon': 119.78, 'lat': 16.13}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 26.97, 'pressure': 1011.49, 'humidity': 91, 'temp_min': 26.97, 'temp_max': 26.97, 'sea_level': 1011.49, 'grnd_level': 1008.35}, 'wind': {'speed': 2.96, 'deg': 6.50162}, 'clouds': {'all': 48}, 'dt': 1553877347, 'sys': {'message': 0.0036, 'country': 'PH', 'sunrise': 1553896672, 'sunset': 1553940779}, 'id': 1731298, 'name': 'Aloleng', 'cod': 200}
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# grand river south east
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weathergrand river south east
# barentsburg
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weatherbarentsburg
# hithadhoo
# {'coord': {'lon': 73.08, 'lat': -0.6}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 28.27, 'pressure': 1012.89, 'humidity': 100, 'temp_min': 28.27, 'temp_max': 28.27, 'sea_level': 1012.89, 'grnd_level': 1012.83}, 'wind': {'speed': 3.31, 'deg': 11.0016}, 'clouds': {'all': 12}, 'dt': 1553877348, 'sys': {'message': 0.0036, 'country': 'MV', 'sunrise': 1553821758, 'sunset': 1553865341}, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# miracema do tocantins
# {'coord': {'lon': -48.4, 'lat': -9.56}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 27.47, 'pressure': 1010.93, 'humidity': 95, 'temp_min': 27.47, 'temp_max': 27.47, 'sea_level': 1010.93, 'grnd_level': 986.11}, 'wind': {'speed': 2.66, 'deg': 105.002}, 'rain': {'3h': 4.005}, 'clouds': {'all': 24}, 'dt': 1553877349, 'sys': {'message': 0.0033, 'country': 'BR', 'sunrise': 1553851031, 'sunset': 1553894367}, 'id': 3384937, 'name': 'Miracema do Tocantins', 'cod': 200}
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# jamestown
# {'coord': {'lon': 138.6, 'lat': -33.21}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 7.77, 'pressure': 1016.45, 'humidity': 78, 'temp_min': 7.77, 'temp_max': 7.77, 'sea_level': 1016.45, 'grnd_level': 957.47}, 'wind': {'speed': 4.81, 'deg': 202.002}, 'clouds': {'all': 8}, 'dt': 1553877349, 'sys': {'message': 0.003, 'country': 'AU', 'sunrise': 1553892923, 'sunset': 1553935496}, 'id': 2069194, 'name': 'Jamestown', 'cod': 200}
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# el tigre
# {'coord': {'lon': -64.25, 'lat': 8.89}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 33.42, 'pressure': 1009.97, 'humidity': 46, 'temp_min': 33.42, 'temp_max': 33.42, 'sea_level': 1009.97, 'grnd_level': 981.63}, 'wind': {'speed': 6.36, 'deg': 74.0016}, 'clouds': {'all': 8}, 'dt': 1553877350, 'sys': {'message': 0.0028, 'country': 'VE', 'sunrise': 1553854574, 'sunset': 1553898429}, 'id': 3641351, 'name': 'El Tigre', 'cod': 200}
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# brunico
# {'coord': {'lon': 11.94, 'lat': 46.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 11.87, 'pressure': 1025, 'humidity': 24, 'temp_min': 2.22, 'temp_max': 19}, 'visibility': 10000, 'wind': {'speed': 2.6, 'deg': 160}, 'clouds': {'all': 0}, 'dt': 1553877006, 'sys': {'type': 1, 'id': 6757, 'message': 0.0039, 'country': 'IT', 'sunrise': 1553835495, 'sunset': 1553880946}, 'id': 3181480, 'name': 'Brunico', 'cod': 200}
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# acarau
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weatheracarau
# nevel
# {'coord': {'lon': 29.92, 'lat': 56.02}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 7.87, 'pressure': 1014.29, 'humidity': 69, 'temp_min': 7.87, 'temp_max': 7.87, 'sea_level': 1014.29, 'grnd_level': 993.63}, 'wind': {'speed': 6.91, 'deg': 286.002}, 'clouds': {'all': 8}, 'dt': 1553877351, 'sys': {'message': 0.0033, 'country': 'RU', 'sunrise': 1553830792, 'sunset': 1553877020}, 'id': 522410, 'name': 'Nevel', 'cod': 200}
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# hobart
# {'coord': {'lon': 147.33, 'lat': -42.88}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 11.01, 'pressure': 1002, 'humidity': 82, 'temp_min': 8.33, 'temp_max': 13}, 'visibility': 10000, 'wind': {'speed': 1.5, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1553877075, 'sys': {'type': 1, 'id': 9545, 'message': 0.0052, 'country': 'AU', 'sunrise': 1553891023, 'sunset': 1553933207}, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# makkaveyevo
# {'coord': {'lon': 113.95, 'lat': 51.75}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -12, 'pressure': 1020, 'humidity': 78, 'temp_min': -12, 'temp_max': -12}, 'visibility': 10000, 'wind': {'speed': 1, 'deg': 280}, 'clouds': {'all': 56}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 8890, 'message': 0.0035, 'country': 'RU', 'sunrise': 1553897122, 'sunset': 1553943127}, 'id': 2020559, 'name': 'Makkaveyevo', 'cod': 200}
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# francavilla al mare
# {'coord': {'lon': 14.29, 'lat': 42.42}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 14.11, 'pressure': 1027, 'humidity': 33, 'temp_min': 11.67, 'temp_max': 15.56}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 360}, 'clouds': {'all': 0}, 'dt': 1553877347, 'sys': {'type': 1, 'id': 6687, 'message': 0.0089, 'country': 'IT', 'sunrise': 1553835071, 'sunset': 1553880242}, 'id': 3176605, 'name': 'Francavilla al Mare', 'cod': 200}
# 34
# 34
# 34
# 34
# 34
# 34
# 34
# busselton
# {'coord': {'lon': 115.35, 'lat': -33.64}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 13.85, 'pressure': 1016, 'humidity': 35, 'temp_min': 12.78, 'temp_max': 15.56}, 'wind': {'speed': 8.11, 'deg': 104.502}, 'clouds': {'all': 0}, 'dt': 1553877323, 'sys': {'type': 3, 'id': 2011706, 'message': 0.0035, 'country': 'AU', 'sunrise': 1553898514, 'sunset': 1553941063}, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# vaitupu
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weathervaitupu
# broken hill
# {'coord': {'lon': 141.45, 'lat': -31.97}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 13, 'pressure': 1014, 'humidity': 43, 'temp_min': 13, 'temp_max': 13}, 'visibility': 10000, 'wind': {'speed': 10.8, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 9491, 'message': 0.0045, 'country': 'AU', 'sunrise': 1553892216, 'sunset': 1553934835}, 'id': 2173911, 'name': 'Broken Hill', 'cod': 200}
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# okha
# {'coord': {'lon': 142.95, 'lat': 53.59}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -12.19, 'pressure': 1013.33, 'humidity': 81, 'temp_min': -12.19, 'temp_max': -12.19, 'sea_level': 1013.33, 'grnd_level': 1010.35}, 'wind': {'speed': 3.71, 'deg': 321.502}, 'clouds': {'all': 48}, 'dt': 1553877354, 'sys': {'message': 0.0036, 'country': 'RU', 'sunrise': 1553890085, 'sunset': 1553936246}, 'id': 2122614, 'name': 'Okha', 'cod': 200}
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# punta arenas
# {'coord': {'lon': -70.91, 'lat': -53.16}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 11.88, 'pressure': 982, 'humidity': 58, 'temp_min': 11.67, 'temp_max': 12}, 'visibility': 10000, 'wind': {'speed': 20.1, 'deg': 250, 'gust': 27.8}, 'clouds': {'all': 40}, 'dt': 1553876547, 'sys': {'type': 1, 'id': 8487, 'message': 0.0048, 'country': 'CL', 'sunrise': 1553857240, 'sunset': 1553898960}, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# provideniya
# {'coord': {'lon': -173.23, 'lat': 64.42}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -0.19, 'pressure': 1015.61, 'humidity': 94, 'temp_min': -0.19, 'temp_max': -0.19, 'sea_level': 1015.61, 'grnd_level': 1009.47}, 'wind': {'speed': 12.91, 'deg': 138.502}, 'clouds': {'all': 92}, 'dt': 1553877355, 'sys': {'message': 0.0041, 'country': 'RU', 'sunrise': 1553965027, 'sunset': 1554013038}, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# 39
# 39
# 39
# 39
# 39
# 39
# 39
# mount isa
# {'coord': {'lon': 139.49, 'lat': -20.73}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 23, 'pressure': 1011, 'humidity': 94, 'temp_min': 23, 'temp_max': 23}, 'visibility': 10000, 'wind': {'speed': 1, 'deg': 190}, 'clouds': {'all': 90}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 9495, 'message': 0.0036, 'country': 'AU', 'sunrise': 1553892502, 'sunset': 1553935491}, 'id': 2065594, 'name': 'Mount Isa', 'cod': 200}
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# aldan
# {'coord': {'lon': 125.39, 'lat': 58.61}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': -16.94, 'pressure': 1023.97, 'humidity': 56, 'temp_min': -16.94, 'temp_max': -16.94, 'sea_level': 1023.97, 'grnd_level': 950.83}, 'wind': {'speed': 1.06, 'deg': 243.502}, 'clouds': {'all': 12}, 'dt': 1553877355, 'sys': {'message': 0.0033, 'country': 'RU', 'sunrise': 1553894004, 'sunset': 1553940755}, 'id': 2027968, 'name': 'Aldan', 'cod': 200}
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# belushya guba
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weatherbelushya guba
# bandarbeyla
# {'coord': {'lon': 50.81, 'lat': 9.49}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 26.47, 'pressure': 1012.65, 'humidity': 100, 'temp_min': 26.47, 'temp_max': 26.47, 'sea_level': 1012.65, 'grnd_level': 1007.71}, 'wind': {'speed': 3.31, 'deg': 48.0016}, 'clouds': {'all': 0}, 'dt': 1553877356, 'sys': {'message': 0.0029, 'country': 'SO', 'sunrise': 1553826962, 'sunset': 1553870825}, 'id': 64814, 'name': 'Bandarbeyla', 'cod': 200}
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# manokwari
# {'coord': {'lon': 134.08, 'lat': -0.87}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 26.57, 'pressure': 1008.29, 'humidity': 100, 'temp_min': 26.57, 'temp_max': 26.57, 'sea_level': 1008.29, 'grnd_level': 1005.71}, 'wind': {'speed': 3.41, 'deg': 298.502}, 'rain': {'3h': 1.525}, 'clouds': {'all': 76}, 'dt': 1553877356, 'sys': {'message': 0.0046, 'country': 'ID', 'sunrise': 1553893507, 'sunset': 1553937081}, 'id': 1636308, 'name': 'Manokwari', 'cod': 200}
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# bogorodskoye
# {'coord': {'lon': 140.44, 'lat': 52.37}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -9.19, 'pressure': 1015.05, 'humidity': 78, 'temp_min': -9.19, 'temp_max': -9.19, 'sea_level': 1015.05, 'grnd_level': 992.19}, 'wind': {'speed': 1.51, 'deg': 309.002}, 'clouds': {'all': 68}, 'dt': 1553877357, 'sys': {'message': 0.0027, 'country': 'RU', 'sunrise': 1553890746, 'sunset': 1553936790}, 'id': 2126638, 'name': 'Bogorodskoye', 'cod': 200}
# 44
# 44
# 44
# 44
# 44
# 44
# 44
# davenda
# {'coord': {'lon': 119.32, 'lat': 53.56}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -14.69, 'pressure': 1024.05, 'humidity': 69, 'temp_min': -14.69, 'temp_max': -14.69, 'sea_level': 1024.05, 'grnd_level': 932.59}, 'wind': {'speed': 1.06, 'deg': 295.002}, 'clouds': {'all': 48}, 'dt': 1553877357, 'sys': {'message': 0.0036, 'country': 'RU', 'sunrise': 1553895748, 'sunset': 1553941923}, 'id': 2021980, 'name': 'Davenda', 'cod': 200}
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# attawapiskat
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weatherattawapiskat
# jaisalmer
# {'coord': {'lon': 70.91, 'lat': 26.91}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 24.22, 'pressure': 1009.49, 'humidity': 38, 'temp_min': 24.22, 'temp_max': 24.22, 'sea_level': 1009.49, 'grnd_level': 986.43}, 'wind': {'speed': 2.81, 'deg': 275.502}, 'clouds': {'all': 0}, 'dt': 1553877285, 'sys': {'message': 0.0035, 'country': 'IN', 'sunrise': 1553821857, 'sunset': 1553866284}, 'id': 1269507, 'name': 'Jaisalmer', 'cod': 200}
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# acajutla
# {'coord': {'lon': -89.83, 'lat': 13.59}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 31.47, 'pressure': 1012.21, 'humidity': 44, 'temp_min': 31.47, 'temp_max': 31.47, 'sea_level': 1012.21, 'grnd_level': 976.59}, 'wind': {'speed': 2.51, 'deg': 180.002}, 'clouds': {'all': 12}, 'dt': 1553877310, 'sys': {'message': 0.0034, 'country': 'SV', 'sunrise': 1553860639, 'sunset': 1553904641}, 'id': 3587498, 'name': 'Acajutla', 'cod': 200}
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# sao filipe
# {'coord': {'lon': -24.5, 'lat': 14.9}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 22.42, 'pressure': 1015.25, 'humidity': 91, 'temp_min': 22.42, 'temp_max': 22.42, 'sea_level': 1015.25, 'grnd_level': 1003.55}, 'wind': {'speed': 7.91, 'deg': 36.0016}, 'clouds': {'all': 0}, 'dt': 1553877218, 'sys': {'message': 0.0034, 'country': 'CV', 'sunrise': 1553844947, 'sunset': 1553888981}, 'id': 3374210, 'name': 'Sao Filipe', 'cod': 200}
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# rikitea
# {'coord': {'lon': -134.97, 'lat': -23.12}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 25.07, 'pressure': 1011.37, 'humidity': 100, 'temp_min': 25.07, 'temp_max': 25.07, 'sea_level': 1011.37, 'grnd_level': 1011.31}, 'wind': {'speed': 4.76, 'deg': 4.50162}, 'clouds': {'all': 92}, 'dt': 1553877359, 'sys': {'message': 0.0035, 'country': 'PF', 'sunrise': 1553872004, 'sunset': 1553914938}, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# kapaa
# {'coord': {'lon': -159.32, 'lat': 22.08}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 18.97, 'pressure': 1016, 'humidity': 88, 'temp_min': 17.78, 'temp_max': 21}, 'visibility': 16093, 'wind': {'speed': 2.1, 'deg': 290}, 'clouds': {'all': 90}, 'dt': 1553877053, 'sys': {'type': 1, 'id': 7873, 'message': 0.0053, 'country': 'US', 'sunrise': 1553877163, 'sunset': 1553921465}, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# san quintin
# {'coord': {'lon': 120.52, 'lat': 17.54}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 21.27, 'pressure': 1011.77, 'humidity': 81, 'temp_min': 21.27, 'temp_max': 21.27, 'sea_level': 1011.77, 'grnd_level': 971.47}, 'wind': {'speed': 0.91, 'deg': 112.502}, 'clouds': {'all': 24}, 'dt': 1553877360, 'sys': {'message': 0.0038, 'country': 'PH', 'sunrise': 1553896471, 'sunset': 1553940625}, 'id': 1688687, 'name': 'San Quintin', 'cod': 200}
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# ilulissat
# {'coord': {'lon': -51.1, 'lat': 69.22}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -7, 'pressure': 1008, 'humidity': 41, 'temp_min': -7, 'temp_max': -7}, 'visibility': 10000, 'wind': {'speed': 7.7, 'deg': 80}, 'clouds': {'all': 75}, 'dt': 1553874600, 'sys': {'type': 1, 'id': 165, 'message': 0.0047, 'country': 'GL', 'sunrise': 1553849063, 'sunset': 1553897630}, 'id': 3423146, 'name': 'Ilulissat', 'cod': 200}
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# vilyuysk
# {'coord': {'lon': 121.63, 'lat': 63.75}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -13.59, 'pressure': 1021.73, 'humidity': 67, 'temp_min': -13.59, 'temp_max': -13.59, 'sea_level': 1021.73, 'grnd_level': 1003.07}, 'wind': {'speed': 1.16, 'deg': 234.502}, 'clouds': {'all': 68}, 'dt': 1553877360, 'sys': {'message': 0.0038, 'country': 'RU', 'sunrise': 1553894503, 'sunset': 1553942060}, 'id': 2013392, 'name': 'Vilyuysk', 'cod': 200}
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# georgetown
# {'coord': {'lon': -58.16, 'lat': 6.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 28.88, 'pressure': 1014, 'humidity': 74, 'temp_min': 28, 'temp_max': 30}, 'visibility': 10000, 'wind': {'speed': 7.2, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1553871600, 'sys': {'type': 1, 'id': 8776, 'message': 0.0045, 'country': 'GY', 'sunrise': 1553853144, 'sunset': 1553896937}, 'id': 3378644, 'name': 'Georgetown', 'cod': 200}
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# new norfolk
# {'coord': {'lon': 147.06, 'lat': -42.78}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 11.03, 'pressure': 1002, 'humidity': 82, 'temp_min': 8.33, 'temp_max': 13}, 'visibility': 10000, 'wind': {'speed': 1.5, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1553877196, 'sys': {'type': 1, 'id': 9545, 'message': 0.0034, 'country': 'AU', 'sunrise': 1553891086, 'sunset': 1553933274}, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# hermanus
# {'coord': {'lon': 19.24, 'lat': -34.42}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 20.98, 'pressure': 1011, 'humidity': 80, 'temp_min': 19.44, 'temp_max': 22.22}, 'wind': {'speed': 1.34, 'deg': 291, 'gust': 4.02}, 'rain': {}, 'clouds': {'all': 0}, 'dt': 1553877095, 'sys': {'type': 3, 'id': 2006131, 'message': 0.0031, 'country': 'ZA', 'sunrise': 1553835161, 'sunset': 1553877776}, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# 56
# 56
# 56
# 56
# 56
# 56
# 56
# vawkavysk
# {'coord': {'lon': 24.45, 'lat': 53.15}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 8.77, 'pressure': 1022.89, 'humidity': 72, 'temp_min': 8.77, 'temp_max': 8.77, 'sea_level': 1022.89, 'grnd_level': 1005.63}, 'wind': {'speed': 8.06, 'deg': 298.502}, 'clouds': {'all': 12}, 'dt': 1553877362, 'sys': {'message': 0.004, 'country': 'BY', 'sunrise': 1553832244, 'sunset': 1553878193}, 'id': 620391, 'name': 'Vawkavysk', 'cod': 200}
# 57
# 57
# 57
# 57
# 57
# 57
# 57
# uwajima
# {'coord': {'lon': 132.57, 'lat': 33.22}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 11.57, 'pressure': 1013.25, 'humidity': 83, 'temp_min': 11.57, 'temp_max': 11.57, 'sea_level': 1013.25, 'grnd_level': 998.99}, 'wind': {'speed': 2.26, 'deg': 94.5016}, 'clouds': {'all': 32}, 'dt': 1553877362, 'sys': {'message': 0.0032, 'country': 'JP', 'sunrise': 1553893264, 'sunset': 1553938049}, 'id': 1926020, 'name': 'Uwajima', 'cod': 200}
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# husavik
# {'coord': {'lon': -96.99, 'lat': 50.56}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 1.97, 'pressure': 1016, 'humidity': 96, 'temp_min': 1.67, 'temp_max': 2.22}, 'wind': {'speed': 5.36, 'deg': 293, 'gust': 7.15}, 'snow': {'3h': 0.0095}, 'clouds': {'all': 48}, 'dt': 1553877333, 'sys': {'type': 3, 'id': 19218, 'message': 0.0043, 'country': 'CA', 'sunrise': 1553861456, 'sunset': 1553907259}, 'id': 5961417, 'name': 'Husavik', 'cod': 200}
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# pacific grove
# {'coord': {'lon': -121.92, 'lat': 36.62}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 11.02, 'pressure': 1028, 'humidity': 76, 'temp_min': 6.67, 'temp_max': 14.44}, 'visibility': 16093, 'wind': {'speed': 2.46, 'deg': 346.502}, 'rain': {'1h': 0.25}, 'clouds': {'all': 1}, 'dt': 1553877316, 'sys': {'type': 1, 'id': 4980, 'message': 0.0071, 'country': 'US', 'sunrise': 1553867883, 'sunset': 1553912796}, 'id': 5380437, 'name': 'Pacific Grove', 'cod': 200}
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# kysyl-syr
# {'coord': {'lon': 122.77, 'lat': 63.9}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -16.69, 'pressure': 1021.69, 'humidity': 58, 'temp_min': -16.69, 'temp_max': -16.69, 'sea_level': 1021.69, 'grnd_level': 1000.19}, 'wind': {'speed': 1.16, 'deg': 194.502}, 'clouds': {'all': 0}, 'dt': 1553877363, 'sys': {'message': 0.0039, 'country': 'RU', 'sunrise': 1553894216, 'sunset': 1553941800}, 'id': 2021017, 'name': 'Kysyl-Syr', 'cod': 200}
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# skalistyy
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weatherskalistyy
# castro
# {'coord': {'lon': -73.76, 'lat': -42.48}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 12, 'pressure': 1016, 'humidity': 81, 'temp_min': 12, 'temp_max': 12}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 340}, 'clouds': {'all': 90}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 8512, 'message': 0.0041, 'country': 'CL', 'sunrise': 1553857650, 'sunset': 1553899918}, 'id': 3896218, 'name': 'Castro', 'cod': 200}
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# port alfred
# {'coord': {'lon': 26.89, 'lat': -33.59}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 21.17, 'pressure': 1016.49, 'humidity': 90, 'temp_min': 21.17, 'temp_max': 21.17, 'sea_level': 1016.49, 'grnd_level': 1007.87}, 'wind': {'speed': 4.81, 'deg': 64.5016}, 'clouds': {'all': 0}, 'dt': 1553877096, 'sys': {'message': 0.0028, 'country': 'ZA', 'sunrise': 1553833310, 'sunset': 1553875956}, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# tsienyane
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weathertsienyane
# korla
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weatherkorla
# nanortalik
# {'coord': {'lon': -45.24, 'lat': 60.14}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 0.12, 'pressure': 1013.21, 'humidity': 99, 'temp_min': 0.12, 'temp_max': 0.12, 'sea_level': 1013.21, 'grnd_level': 1001.07}, 'wind': {'speed': 4.66, 'deg': 179.502}, 'clouds': {'all': 92}, 'dt': 1553877366, 'sys': {'message': 0.0041, 'country': 'GL', 'sunrise': 1553848546, 'sunset': 1553895335}, 'id': 3421765, 'name': 'Nanortalik', 'cod': 200}
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# bluff
# {'coord': {'lon': 149.07, 'lat': -23.58}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 22.57, 'pressure': 1008.33, 'humidity': 96, 'temp_min': 22.57, 'temp_max': 22.57, 'sea_level': 1008.33, 'grnd_level': 986.11}, 'wind': {'speed': 3.06, 'deg': 10.0016}, 'rain': {'3h': 0.39}, 'clouds': {'all': 92}, 'dt': 1553877095, 'sys': {'message': 0.0041, 'country': 'AU', 'sunrise': 1553890246, 'sunset': 1553933148}, 'id': 2175403, 'name': 'Bluff', 'cod': 200}
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# san luis
# {'coord': {'lon': -66.34, 'lat': -33.3}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 27.67, 'pressure': 1011.61, 'humidity': 45, 'temp_min': 27.67, 'temp_max': 27.67, 'sea_level': 1011.61, 'grnd_level': 954.75}, 'wind': {'speed': 4.91, 'deg': 347.002}, 'clouds': {'all': 0}, 'dt': 1553877097, 'sys': {'message': 0.0034, 'country': 'AR', 'sunrise': 1553855692, 'sunset': 1553898315}, 'id': 3837056, 'name': 'San Luis', 'cod': 200}
# 66
# 66
# 66
# 66
# 66
# 66
# 66
# ahipara
# {'coord': {'lon': 173.16, 'lat': -35.17}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 18.37, 'pressure': 1022.49, 'humidity': 97, 'temp_min': 18.37, 'temp_max': 18.37, 'sea_level': 1022.49, 'grnd_level': 1009.31}, 'wind': {'speed': 4.66, 'deg': 91.0016}, 'clouds': {'all': 92}, 'dt': 1553877367, 'sys': {'message': 0.0035, 'country': 'NZ', 'sunrise': 1553884661, 'sunset': 1553927174}, 'id': 2194098, 'name': 'Ahipara', 'cod': 200}
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# placido de castro
# {'coord': {'lon': -67.19, 'lat': -10.34}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 29.57, 'pressure': 1011.85, 'humidity': 71, 'temp_min': 29.57, 'temp_max': 29.57, 'sea_level': 1011.85, 'grnd_level': 991.95}, 'wind': {'speed': 1.36, 'deg': 136.502}, 'clouds': {'all': 80}, 'dt': 1553877368, 'sys': {'message': 0.0029, 'country': 'BR', 'sunrise': 1553855551, 'sunset': 1553898864}, 'id': 3924895, 'name': 'Placido de Castro', 'cod': 200}
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# guilin
# {'coord': {'lon': 110.29, 'lat': 25.28}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 16, 'pressure': 1014, 'humidity': 93, 'temp_min': 16, 'temp_max': 16}, 'visibility': 8000, 'wind': {'speed': 1.21, 'deg': 39.0016}, 'clouds': {'all': 48}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 9626, 'message': 0.0033, 'country': 'CN', 'sunrise': 1553898780, 'sunset': 1553943225}, 'id': 1809498, 'name': 'Guilin', 'cod': 200}
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# kilemary
# {'coord': {'lon': 46.86, 'lat': 56.78}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -1.69, 'pressure': 1011.01, 'humidity': 85, 'temp_min': -1.69, 'temp_max': -1.69, 'sea_level': 1011.01, 'grnd_level': 995.55}, 'wind': {'speed': 3.61, 'deg': 279.502}, 'clouds': {'all': 0}, 'dt': 1553877369, 'sys': {'message': 0.0038, 'country': 'RU', 'sunrise': 1553826693, 'sunset': 1553872989}, 'id': 548715, 'name': 'Kilemary', 'cod': 200}
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# kargil
# {'coord': {'lon': 76.13, 'lat': 34.56}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -8.44, 'pressure': 1017.65, 'humidity': 88, 'temp_min': -8.44, 'temp_max': -8.44, 'sea_level': 1017.65, 'grnd_level': 617.31}, 'wind': {'speed': 0.61, 'deg': 127.502}, 'clouds': {'all': 92}, 'dt': 1553877369, 'sys': {'message': 0.0031, 'country': 'PK', 'sunrise': 1553820448, 'sunset': 1553865188}, 'id': 1267776, 'name': 'Kargil', 'cod': 200}
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# aksha
# {'coord': {'lon': 113.29, 'lat': 50.28}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -11.09, 'pressure': 1026.05, 'humidity': 67, 'temp_min': -11.09, 'temp_max': -11.09, 'sea_level': 1026.05, 'grnd_level': 912.99}, 'wind': {'speed': 1.31, 'deg': 267.002}, 'clouds': {'all': 48}, 'dt': 1553877370, 'sys': {'message': 0.0039, 'country': 'RU', 'sunrise': 1553897346, 'sunset': 1553943220}, 'id': 2028028, 'name': 'Aksha', 'cod': 200}
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# avarua
# {'coord': {'lon': -159.78, 'lat': -21.21}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 25, 'pressure': 1011, 'humidity': 78, 'temp_min': 25, 'temp_max': 25}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 110}, 'clouds': {'all': 88}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 7271, 'message': 0.0052, 'country': 'CK', 'sunrise': 1553877931, 'sunset': 1553920917}, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# tuktoyaktuk
# {'coord': {'lon': -133.03, 'lat': 69.44}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -7, 'pressure': 1024, 'humidity': 85, 'temp_min': -7, 'temp_max': -7}, 'visibility': 24140, 'wind': {'speed': 5.7, 'deg': 250}, 'clouds': {'all': 90}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 942, 'message': 0.004, 'country': 'CA', 'sunrise': 1553868632, 'sunset': 1553917379}, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# 74
# 74
# 74
# 74
# 74
# 74
# 74
# mindelo
# {'coord': {'lon': -8.72, 'lat': 41.31}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 20.41, 'pressure': 1019, 'humidity': 52, 'temp_min': 18, 'temp_max': 21.67}, 'visibility': 10000, 'wind': {'speed': 2.6, 'deg': 280}, 'clouds': {'all': 0}, 'dt': 1553877018, 'sys': {'type': 1, 'id': 6900, 'message': 0.0043, 'country': 'PT', 'sunrise': 1553840619, 'sunset': 1553885736}, 'id': 2739997, 'name': 'Mindelo', 'cod': 200}
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# talara
# {'coord': {'lon': -81.27, 'lat': -4.58}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 17, 'pressure': 1012, 'humidity': 290, 'temp_min': 17, 'temp_max': 17}, 'visibility': 10000, 'wind': {'speed': 4.56, 'deg': 274.002}, 'clouds': {'all': 40}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 8685, 'message': 0.0036, 'country': 'PE', 'sunrise': 1553858850, 'sunset': 1553902321}, 'id': 3691582, 'name': 'Talara', 'cod': 200}
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# sexsmith
# {'coord': {'lon': -118.78, 'lat': 55.35}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 3.38, 'pressure': 1026, 'humidity': 83, 'temp_min': 0, 'temp_max': 6.11}, 'visibility': 40233, 'wind': {'speed': 2.6, 'deg': 210}, 'clouds': {'all': 40}, 'dt': 1553877138, 'sys': {'type': 1, 'id': 900, 'message': 0.0044, 'country': 'CA', 'sunrise': 1553866451, 'sunset': 1553912721}, 'id': 6144602, 'name': 'Sexsmith', 'cod': 200}
# 77
# 77
# 77
# 77
# 77
# 77
# 77
# lalmohan
# {'coord': {'lon': 90.74, 'lat': 22.34}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 25.42, 'pressure': 1009.37, 'humidity': 91, 'temp_min': 25.42, 'temp_max': 25.42, 'sea_level': 1009.37, 'grnd_level': 1009.23}, 'wind': {'speed': 4.16, 'deg': 225.002}, 'clouds': {'all': 8}, 'dt': 1553877372, 'sys': {'message': 0.0029, 'country': 'BD', 'sunrise': 1553817184, 'sunset': 1553861441}, 'id': 1185251, 'name': 'Lalmohan', 'cod': 200}
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# sjenica
# {'coord': {'lon': 20, 'lat': 43.27}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 4.57, 'pressure': 1026.77, 'humidity': 48, 'temp_min': 4.57, 'temp_max': 4.57, 'sea_level': 1026.77, 'grnd_level': 897.23}, 'wind': {'speed': 2.71, 'deg': 17.5016}, 'clouds': {'all': 0}, 'dt': 1553877373, 'sys': {'message': 0.0031, 'country': 'RS', 'sunrise': 1553833677, 'sunset': 1553878896}, 'id': 3190776, 'name': 'Sjenica', 'cod': 200}
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# novoagansk
# {'coord': {'lon': 76.66, 'lat': 61.94}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 1.52, 'pressure': 1012.85, 'humidity': 80, 'temp_min': 1.52, 'temp_max': 1.52, 'sea_level': 1012.85, 'grnd_level': 1003.87}, 'wind': {'speed': 3.66, 'deg': 152.002}, 'clouds': {'all': 92}, 'dt': 1553877373, 'sys': {'message': 0.0035, 'country': 'RU', 'sunrise': 1553819225, 'sunset': 1553866156}, 'id': 1497210, 'name': 'Novoagansk', 'cod': 200}
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# nikolskoye
# {'coord': {'lon': 30.79, 'lat': 59.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 6, 'pressure': 1006, 'humidity': 66, 'temp_min': 3.89, 'temp_max': 9}, 'visibility': 10000, 'wind': {'speed': 7, 'deg': 250}, 'clouds': {'all': 0}, 'dt': 1553876993, 'sys': {'type': 1, 'id': 8926, 'message': 0.0053, 'country': 'RU', 'sunrise': 1553830367, 'sunset': 1553877027}, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# bredasdorp
# {'coord': {'lon': 20.04, 'lat': -34.53}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 20.9, 'pressure': 1014, 'humidity': 69, 'temp_min': 19.44, 'temp_max': 23}, 'wind': {'speed': 2.6, 'deg': 210}, 'clouds': {'all': 0}, 'dt': 1553877095, 'sys': {'type': 1, 'id': 1966, 'message': 0.004, 'country': 'ZA', 'sunrise': 1553834971, 'sunset': 1553877582}, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# port elizabeth
# {'coord': {'lon': -74.98, 'lat': 39.31}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 15.88, 'pressure': 1020, 'humidity': 51, 'temp_min': 12.22, 'temp_max': 19.44}, 'visibility': 16093, 'wind': {'speed': 2.6, 'deg': 250}, 'clouds': {'all': 90}, 'dt': 1553877368, 'sys': {'type': 1, 'id': 4902, 'message': 0.0054, 'country': 'US', 'sunrise': 1553856559, 'sunset': 1553901594}, 'id': 4501427, 'name': 'Port Elizabeth', 'cod': 200}
# 83
# 83
# 83
# 83
# 83
# 83
# 83
# chuy
# {'coord': {'lon': -53.46, 'lat': -33.69}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 23.97, 'pressure': 1020.25, 'humidity': 77, 'temp_min': 23.97, 'temp_max': 23.97, 'sea_level': 1020.25, 'grnd_level': 1018.59}, 'wind': {'speed': 7.86, 'deg': 49.0016}, 'clouds': {'all': 76}, 'dt': 1553877375, 'sys': {'message': 0.0033, 'country': 'UY', 'sunrise': 1553852606, 'sunset': 1553895220}, 'id': 3443061, 'name': 'Chuy', 'cod': 200}
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# castro-urdiales
# {'coord': {'lon': -3.22, 'lat': 43.38}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 16.58, 'pressure': 1019, 'humidity': 45, 'temp_min': 12.78, 'temp_max': 21.67}, 'visibility': 10000, 'wind': {'speed': 4.6, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1553877365, 'sys': {'type': 1, 'id': 6395, 'message': 0.0035, 'country': 'ES', 'sunrise': 1553839240, 'sunset': 1553884476}, 'id': 3125621, 'name': 'Castro-Urdiales', 'cod': 200}
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# kaitangata
# {'coord': {'lon': 169.85, 'lat': -46.28}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 6.67, 'pressure': 1025, 'humidity': 91, 'temp_min': 6.67, 'temp_max': 6.67}, 'wind': {'speed': 1.34, 'deg': 293, 'gust': 3.13}, 'clouds': {'all': 0}, 'dt': 1553877339, 'sys': {'type': 3, 'id': 2000217, 'message': 0.0034, 'country': 'NZ', 'sunrise': 1553885696, 'sunset': 1553927727}, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# 86
# 86
# 86
# 86
# 86
# 86
# 86
# beidao
# ...
# 530
# 530
# 530
# 530
# 530
# 530
# 530
# iisalmi
# {'coord': {'lon': 27.19, 'lat': 63.56}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 8, 'pressure': 997, 'humidity': 62, 'temp_min': 8, 'temp_max': 8}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 260}, 'clouds': {'all': 0}, 'dt': 1553876400, 'sys': {'type': 1, 'id': 1345, 'message': 0.0037, 'country': 'FI', 'sunrise': 1553830941, 'sunset': 1553878181}, 'id': 656820, 'name': 'Iisalmi', 'cod': 200}
# 531
# 531
# 531
# 531
# 531
# 531
# 531
# port antonio
# {'coord': {'lon': -76.45, 'lat': 18.18}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 29, 'pressure': 1014, 'humidity': 54, 'temp_min': 29, 'temp_max': 29}, 'visibility': 10000, 'wind': {'speed': 2.6, 'deg': 170}, 'clouds': {'all': 40}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 7105, 'message': 0.0031, 'country': 'JM', 'sunrise': 1553857355, 'sunset': 1553901504}, 'id': 3489005, 'name': 'Port Antonio', 'cod': 200}
# 532
# 532
# 532
# 532
# 532
# 532
# 532
# omutinskoye
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weatheromutinskoye
# zheleznodorozhnyy
# {'coord': {'lon': 38, 'lat': 55.75}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 2.37, 'pressure': 1012, 'humidity': 86, 'temp_min': 2, 'temp_max': 3}, 'visibility': 8000, 'wind': {'speed': 2, 'deg': 200}, 'clouds': {'all': 90}, 'dt': 1553876036, 'sys': {'type': 1, 'id': 9020, 'message': 0.0037, 'country': 'RU', 'sunrise': 1553828871, 'sunset': 1553875063}, 'id': 463355, 'name': 'Zheleznodorozhnyy', 'cod': 200}
# 533
# 533
# 533
# 533
# 533
# 533
# 533
# himora
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weatherhimora
# genhe
# {'coord': {'lon': 121.52, 'lat': 50.78}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': -20.34, 'pressure': 1023.13, 'humidity': 48, 'temp_min': -20.34, 'temp_max': -20.34, 'sea_level': 1023.13, 'grnd_level': 905.71}, 'wind': {'speed': 1.26, 'deg': 270.002}, 'clouds': {'all': 20}, 'dt': 1553877586, 'sys': {'message': 0.0037, 'country': 'CN', 'sunrise': 1553895352, 'sunset': 1553941264}, 'id': 2037252, 'name': 'Genhe', 'cod': 200}
# 534
# 534
# 534
# 534
# 534
# 534
# 534
# matagami
# {'coord': {'lon': 8.4, 'lat': 9.67}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 31.77, 'pressure': 1006.25, 'humidity': 22, 'temp_min': 31.77, 'temp_max': 31.77, 'sea_level': 1006.25, 'grnd_level': 920.19}, 'wind': {'speed': 3.21, 'deg': 54.5016}, 'clouds': {'all': 0}, 'dt': 1553877587, 'sys': {'message': 0.0059, 'country': 'NG', 'sunrise': 1553837134, 'sunset': 1553881006}, 'id': 2335713, 'name': 'Matagami', 'cod': 200}
# 535
# 535
# 535
# 535
# 535
# 535
# 535
# szydlowiec
# {'coord': {'lon': 20.86, 'lat': 51.23}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 10.69, 'pressure': 1028, 'humidity': 71, 'temp_min': 8.89, 'temp_max': 12.78}, 'visibility': 10000, 'wind': {'speed': 4.6, 'deg': 280}, 'clouds': {'all': 75}, 'dt': 1553877512, 'sys': {'type': 1, 'id': 1699, 'message': 0.004, 'country': 'PL', 'sunrise': 1553833188, 'sunset': 1553878971}, 'id': 757178, 'name': 'Szydlowiec', 'cod': 200}
# 536
# 536
# 536
# 536
# 536
# 536
# 536
# tabiauea
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weathertabiauea
# sovetskiy
# {'coord': {'lon': 48.47, 'lat': 56.76}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 0.62, 'pressure': 1009.37, 'humidity': 94, 'temp_min': 0.62, 'temp_max': 0.62, 'sea_level': 1009.37, 'grnd_level': 988.99}, 'wind': {'speed': 4.21, 'deg': 299.502}, 'clouds': {'all': 92}, 'dt': 1553877588, 'sys': {'message': 0.0042, 'country': 'RU', 'sunrise': 1553826309, 'sunset': 1553872601}, 'id': 490040, 'name': 'Sovetskiy', 'cod': 200}
# 537
# 537
# 537
# 537
# 537
# 537
# 537
# san rafael
# {'coord': {'lon': -68.33, 'lat': -34.61}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 28.42, 'pressure': 1010.21, 'humidity': 33, 'temp_min': 28.42, 'temp_max': 28.42, 'sea_level': 1010.21, 'grnd_level': 911.07}, 'wind': {'speed': 3.81, 'deg': 32.5016}, 'clouds': {'all': 0}, 'dt': 1553877292, 'sys': {'message': 0.0028, 'country': 'AR', 'sunrise': 1553856193, 'sunset': 1553898769}, 'id': 3836669, 'name': 'San Rafael', 'cod': 200}
# 538
# 538
# 538
# 538
# 538
# 538
# 538
# bosaso
# {'coord': {'lon': 49.18, 'lat': 11.28}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 26.07, 'pressure': 1012.37, 'humidity': 100, 'temp_min': 26.07, 'temp_max': 26.07, 'sea_level': 1012.37, 'grnd_level': 1004.35}, 'wind': {'speed': 3.66, 'deg': 65.5016}, 'clouds': {'all': 0}, 'dt': 1553877589, 'sys': {'message': 0.0034, 'country': 'SO', 'sunrise': 1553827327, 'sunset': 1553871242}, 'id': 64013, 'name': 'Bosaso', 'cod': 200}
# 539
# 539
# 539
# 539
# 539
# 539
# 539
# vila velha
# {'coord': {'lon': -38.6, 'lat': -3.71}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 30.51, 'pressure': 1012, 'humidity': 55, 'temp_min': 29.44, 'temp_max': 31.11}, 'visibility': 10000, 'wind': {'speed': 6.2, 'deg': 130}, 'clouds': {'all': 40}, 'dt': 1553877492, 'sys': {'type': 1, 'id': 8363, 'message': 0.004, 'country': 'BR', 'sunrise': 1553848599, 'sunset': 1553892096}, 'id': 6320062, 'name': 'Vila Velha', 'cod': 200}
# 540
# 540
# 540
# 540
# 540
# 540
# 540
# koungou
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weatherkoungou
# lampazos de naranjo
# {'coord': {'lon': -100.51, 'lat': 27.02}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 26.77, 'pressure': 1012.37, 'humidity': 54, 'temp_min': 26.77, 'temp_max': 26.77, 'sea_level': 1012.37, 'grnd_level': 948.19}, 'wind': {'speed': 1.41, 'deg': 36.5016}, 'clouds': {'all': 0}, 'dt': 1553877316, 'sys': {'message': 0.0048, 'country': 'MX', 'sunrise': 1553862964, 'sunset': 1553907440}, 'id': 4001240, 'name': 'Lampazos de Naranjo', 'cod': 200}
# 541
# 541
# 541
# 541
# 541
# 541
# 541
# kilis
# {'coord': {'lon': 37.12, 'lat': 36.72}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 8.73, 'pressure': 1011, 'humidity': 87, 'temp_min': 8.33, 'temp_max': 9}, 'visibility': 10000, 'wind': {'speed': 1.5, 'deg': 90}, 'clouds': {'all': 90}, 'dt': 1553877342, 'sys': {'type': 1, 'id': 6952, 'message': 0.0044, 'country': 'TR', 'sunrise': 1553829750, 'sunset': 1553874606}, 'id': 307864, 'name': 'Kilis', 'cod': 200}
# 542
# 542
# 542
# 542
# 542
# 542
# 542
# yerbogachen
# {'coord': {'lon': 108.01, 'lat': 61.28}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -4.99, 'pressure': 1024.77, 'humidity': 86, 'temp_min': -4.99, 'temp_max': -4.99, 'sea_level': 1024.77, 'grnd_level': 983.07}, 'wind': {'speed': 2.66, 'deg': 329.502}, 'clouds': {'all': 32}, 'dt': 1553877591, 'sys': {'message': 0.0029, 'country': 'RU', 'sunrise': 1553897975, 'sunset': 1553945125}, 'id': 2012956, 'name': 'Yerbogachen', 'cod': 200}
# 543
# 543
# 543
# 543
# 543
# 543
# 543
# vao
# {'coord': {'lon': 26.19, 'lat': 59.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 3.47, 'pressure': 1009.13, 'humidity': 86, 'temp_min': 3.47, 'temp_max': 3.47, 'sea_level': 1009.13, 'grnd_level': 1001.31}, 'wind': {'speed': 5.16, 'deg': 267.002}, 'clouds': {'all': 0}, 'dt': 1553877591, 'sys': {'message': 0.0054, 'country': 'EE', 'sunrise': 1553831508, 'sunset': 1553878094}, 'id': 588365, 'name': 'Vao', 'cod': 200}
# 544
# 544
# 544
# 544
# 544
# 544
# 544
# karratha
# {'coord': {'lon': 116.85, 'lat': -20.74}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 25.67, 'pressure': 1008.41, 'humidity': 71, 'temp_min': 25.67, 'temp_max': 25.67, 'sea_level': 1008.41, 'grnd_level': 995.31}, 'wind': {'speed': 2.36, 'deg': 237.502}, 'clouds': {'all': 48}, 'dt': 1553877592, 'sys': {'message': 0.0038, 'country': 'AU', 'sunrise': 1553897936, 'sunset': 1553940921}, 'id': 6620339, 'name': 'Karratha', 'cod': 200}
# 545
# 545
# 545
# 545
# 545
# 545
# 545
# pandan
# {'coord': {'lon': 122.09, 'lat': 11.72}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 26.67, 'pressure': 1010.77, 'humidity': 99, 'temp_min': 26.67, 'temp_max': 26.67, 'sea_level': 1010.77, 'grnd_level': 1008.83}, 'wind': {'speed': 4.31, 'deg': 75.5016}, 'clouds': {'all': 0}, 'dt': 1553877592, 'sys': {'message': 0.003, 'country': 'PH', 'sunrise': 1553896192, 'sunset': 1553940151}, 'id': 1695555, 'name': 'Pandan', 'cod': 200}
# 546
# 546
# 546
# 546
# 546
# 546
# 546
# granby
# {'coord': {'lon': -72.73, 'lat': 45.41}, 'weather': [{'id': 301, 'main': 'Drizzle', 'description': 'drizzle', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 5.42, 'pressure': 1017, 'humidity': 100, 'temp_min': 3.89, 'temp_max': 7.22}, 'visibility': 1609, 'wind': {'speed': 1.61, 'deg': 302.502}, 'clouds': {'all': 90}, 'dt': 1553877312, 'sys': {'type': 1, 'id': 4146, 'message': 0.0056, 'country': 'CA', 'sunrise': 1553855835, 'sunset': 1553901238}, 'id': 5964215, 'name': 'Granby', 'cod': 200}
# 547
# 547
# 547
# 547
# 547
# 547
# 547
# tartus
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weathertartus
# tolbazy
# {'coord': {'lon': 55.89, 'lat': 54.01}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 0.71, 'pressure': 1011, 'humidity': 80, 'temp_min': 0.56, 'temp_max': 1}, 'visibility': 10000, 'wind': {'speed': 6, 'deg': 190}, 'clouds': {'all': 90}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 9050, 'message': 0.0034, 'country': 'RU', 'sunrise': 1553824671, 'sunset': 1553870678}, 'id': 482432, 'name': 'Tolbazy', 'cod': 200}
# 548
# 548
# 548
# 548
# 548
# 548
# 548
# bubaque
# {'coord': {'lon': -15.83, 'lat': 11.28}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 31.47, 'pressure': 1008.61, 'humidity': 73, 'temp_min': 31.47, 'temp_max': 31.47, 'sea_level': 1008.61, 'grnd_level': 1008.19}, 'wind': {'speed': 4.96, 'deg': 319.502}, 'clouds': {'all': 0}, 'dt': 1553877594, 'sys': {'message': 0.0027, 'country': 'GW', 'sunrise': 1553842923, 'sunset': 1553886845}, 'id': 2374583, 'name': 'Bubaque', 'cod': 200}
# 549
# 549
# 549
# 549
# 549
# 549
# 549
# abha
# {'coord': {'lon': 42.5, 'lat': 18.22}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 19.52, 'pressure': 1024, 'humidity': 63, 'temp_min': 19, 'temp_max': 20}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 140}, 'clouds': {'all': 20}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 7396, 'message': 0.0036, 'country': 'SA', 'sunrise': 1553828822, 'sunset': 1553872952}, 'id': 110690, 'name': 'Abha', 'cod': 200}
# 550
# 550
# 550
# 550
# 550
# 550
# 550
# sinnamary
# {'coord': {'lon': -52.96, 'lat': 5.38}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 28.57, 'pressure': 1011.89, 'humidity': 84, 'temp_min': 28.57, 'temp_max': 28.57, 'sea_level': 1011.89, 'grnd_level': 1010.59}, 'wind': {'speed': 5.21, 'deg': 78.5016}, 'clouds': {'all': 48}, 'dt': 1553877594, 'sys': {'message': 0.0033, 'country': 'GF', 'sunrise': 1553851917, 'sunset': 1553895669}, 'id': 3380290, 'name': 'Sinnamary', 'cod': 200}
# 551
# 551
# 551
# 551
# 551
# 551
# 551
# lebork
# {'coord': {'lon': 17.75, 'lat': 54.54}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 10.46, 'pressure': 1025, 'humidity': 66, 'temp_min': 9.44, 'temp_max': 11.67}, 'visibility': 10000, 'wind': {'speed': 9.3, 'deg': 270}, 'clouds': {'all': 20}, 'dt': 1553877545, 'sys': {'type': 1, 'id': 1696, 'message': 0.0047, 'country': 'PL', 'sunrise': 1553833784, 'sunset': 1553879869}, 'id': 3093739, 'name': 'Lebork', 'cod': 200}
# 552
# 552
# 552
# 552
# 552
# 552
# 552
# merauke
# {'coord': {'lon': 140.4, 'lat': -8.49}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 25.57, 'pressure': 1007.85, 'humidity': 100, 'temp_min': 25.57, 'temp_max': 25.57, 'sea_level': 1007.85, 'grnd_level': 1007.31}, 'wind': {'speed': 4.96, 'deg': 336.002}, 'rain': {'3h': 0.12}, 'clouds': {'all': 68}, 'dt': 1553877595, 'sys': {'message': 0.0047, 'country': 'ID', 'sunrise': 1553892102, 'sunset': 1553935454}, 'id': 2082539, 'name': 'Merauke', 'cod': 200}
# 553
# 553
# 553
# 553
# 553
# 553
# 553
# hue
# {'coord': {'lon': 107.58, 'lat': 16.47}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 26, 'pressure': 1010, 'humidity': 100, 'temp_min': 26, 'temp_max': 26}, 'visibility': 6000, 'wind': {'speed': 1.5, 'deg': 290}, 'clouds': {'all': 75}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 9310, 'message': 0.0036, 'country': 'VN', 'sunrise': 1553813240, 'sunset': 1553857304}, 'id': 1580240, 'name': 'Hue', 'cod': 200}
# 554
# 554
# 554
# 554
# 554
# 554
# 554
# kirkland lake
# {'coord': {'lon': -80.03, 'lat': 48.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': -5, 'pressure': 1021, 'humidity': 57, 'temp_min': -5, 'temp_max': -5}, 'visibility': 14484, 'wind': {'speed': 2.6, 'deg': 130}, 'clouds': {'all': 1}, 'dt': 1553875200, 'sys': {'type': 1, 'id': 981, 'message': 0.0049, 'country': 'CA', 'sunrise': 1553857488, 'sunset': 1553903089}, 'id': 5992836, 'name': 'Kirkland Lake', 'cod': 200}
# 555
# 555
# 555
# 555
# 555
# 555
# 555
# taltal
# {'coord': {'lon': -70.49, 'lat': -25.41}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 20.92, 'pressure': 1012.61, 'humidity': 68, 'temp_min': 20.92, 'temp_max': 20.92, 'sea_level': 1012.61, 'grnd_level': 858.99}, 'wind': {'speed': 1.56, 'deg': 208.002}, 'clouds': {'all': 76}, 'dt': 1553877596, 'sys': {'message': 0.0038, 'country': 'CL', 'sunrise': 1553856560, 'sunset': 1553899438}, 'id': 3870243, 'name': 'Taltal', 'cod': 200}
# 556
# 556
# 556
# 556
# 556
# 556
# 556
# meyungs
# {'cod': '404', 'message': 'city not found'}
# Error retrieving city weathermeyungs
# bonavista
# {'coord': {'lon': -53.11, 'lat': 48.65}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 2.22, 'pressure': 1026, 'humidity': 71, 'temp_min': 2.22, 'temp_max': 2.22}, 'wind': {'speed': 4.02, 'deg': 110, 'gust': 9.83}, 'clouds': {'all': 48}, 'dt': 1553877133, 'sys': {'type': 3, 'id': 2011050, 'message': 0.0048, 'country': 'CA', 'sunrise': 1553851017, 'sunset': 1553896640}, 'id': 5905393, 'name': 'Bonavista', 'cod': 200}
# 557
# 557
# 557
# 557
# 557
# 557
# 557
# kuybyshevo
# {'coord': {'lon': 33.86, 'lat': 44.63}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 5.27, 'pressure': 1025.85, 'humidity': 100, 'temp_min': 5.27, 'temp_max': 5.27, 'sea_level': 1025.85, 'grnd_level': 1012.35}, 'wind': {'speed': 3.71, 'deg': 10.5016}, 'clouds': {'all': 0}, 'dt': 1553877597, 'sys': {'message': 0.0048, 'country': 'UA', 'sunrise': 1553830313, 'sunset': 1553875608}, 'id': 712969, 'name': 'Kuybyshevo', 'cod': 200}
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558

# %%
city_weather_df = pd.DataFrame({"City": city_list,"Latitude": lat_list,"Longitude": lng_list,"Max Temp (C)": maxtemp_list
                                , "Wind Speed (kph)": wind_list, "Cloudiness Percent": cloud_list, "Humidity Percent": humidity_list})

city_weather_df.to_csv("City Weather DF")
city_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 7 columns):
# City                  558 non-null object
# Latitude              558 non-null float64
# Longitude             558 non-null float64
# Max Temp (C)          558 non-null float64
# Wind Speed (kph)      558 non-null float64
# Cloudiness Percent    558 non-null int64
# Humidity Percent      558 non-null int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 30.6+ KB

# %%
city_weather_df.head(15)
# Out:
#                City  Latitude  Longitude  Max Temp (C)  Wind Speed (kph)  \
# 0            Albany     42.65     -73.75          8.33              3.10
# 1            Barrow    -38.31     -60.23         24.27              7.36
# 2    Ribeira Grande     38.52     -28.70         16.00              3.60
# 3            Dikson     73.51      80.55         -4.04              7.96
# 4            Weinan     34.50     109.46         15.00              5.00
# 5       Keti Bandar     24.14      67.45         26.52              7.61
# 6           Iqaluit     63.75     -68.52         -4.00              4.60
# 7           Qaanaaq     77.48     -69.36        -19.94              3.91
# 8           Ushuaia    -54.81     -68.31         14.00             16.50
# 9              Hilo     19.71    -155.08         18.00              2.60
# 10  Verkhnevilyuysk     63.45     120.31        -11.74              1.16
# 11             Hovd     63.83      10.70          4.44              3.60
# 12            Vaini     15.34      74.49         22.57              1.46
# 13  Plettenberg Bay    -34.05      23.37         19.27              4.01
# 14       Sungairaya      0.70     108.90         24.87              1.21
#
#     Cloudiness Percent  Humidity Percent
# 0                   90                81
# 1                   36                59
# 2                   20                63
# 3                   76                95
# 4                    0                12
# 5                    8                84
# 6                   90                85
# 7                   12                75
# 8                   75                58
# 9                   40                72
# 10                  64                58
# 11                  75                93
# 12                   0                87
# 13                   0                99
# 14                  36                90

# %%
city_weather_df.plot(kind="scatter",
                     x="Latitude",
                     y="Max Temp (C)",
                    title= "City Latitude vs Max Temperature (3/29/19)")
plt.savefig('Temp_plot.png')

# %%
city_weather_df.plot(kind="scatter",
                     x="Latitude",
                     y="Humidity Percent",
                    title= "City Latitude vs Humidity (3/29/19)",
                    ylim= (-20,125))
plt.savefig('Humidity_plot.png')

# %%
city_weather_df.plot(kind="scatter",
                     x="Latitude",
                     y="Cloudiness Percent",
                    title= "City Latitude vs Cloudiness (3/29/19)",
                    ylim= (-20,125))
plt.savefig('Cloudiness_plot.png')

# %%
city_weather_df.plot(kind="scatter",
                     x="Latitude",
                     y="Wind Speed (kph)",
                    title= "City Latitude vs Wind Speed (3/29/19)",
                    ylim= (-5,25))
plt.savefig('Wind_plot.png')
